# %%
import pandas as pd

# %%
filename= r'C:\perfil_eleitorado_ATUAL.csv'
df = pd.read_csv(filename, encoding='latin-1', sep=';')

# %%
df['CD_GENERO'].value_counts()
# Out:
# 4    2267708
# 2    2028104
# 0      22220
# Name: CD_GENERO, dtype: int64

# %%
df['DS_GENERO'].value_counts()
# Out:
# FEMININO         2267708
# MASCULINO        2028104
# NÃO INFORMADO      22220
# Name: DS_GENERO, dtype: int64

# %%
#4 Feminino
#2 Masculino
#0 Não informado

# %%
df.groupby('DS_GENERO').size().sort_values().tail(5).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='DS_GENERO'>

# %%
df.groupby('SG_UF').size().sort_values().tail(27).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='SG_UF'>

# %%
df['DS_FAIXA_ETARIA'].value_counts()
# Out:
# 55 a 59 anos        361773
# 60 a 64 anos        352612
# 50 a 54 anos        351879
# 45 a 49 anos        330018
# 65 a 69 anos        327730
# 40 a 44 anos        312473
# 70 a 74 anos        289681
# 35 a 39 anos        284049
# 30 a 34 anos        245243
# 75 a 79 anos        241960
# 25 a 29 anos        204321
# 80 a 84 anos        198194
# 21 a 24 anos        151998
# 85 a 89 anos        147160
# 90 a 94 anos        105876
# 20 anos              84393
# 19 anos              76257
# 95 a 99 anos         67671
# 18 anos              64787
# 17 anos              49382
# 16 anos              33992
# 100 anos ou mais     26283
# Inválido             10300
# Name: DS_FAIXA_ETARIA, dtype: int64

# %%
df.groupby('DS_FAIXA_ETARIA').size().sort_values().tail(20).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='DS_FAIXA_ETARIA'>

# %%
masculino = df[(df['CD_GENERO']==2)]

# %%
masculino['DS_FAIXA_ETARIA'].value_counts()
# Out:
# 55 a 59 anos        170378
# 60 a 64 anos        168225
# 50 a 54 anos        164180
# 65 a 69 anos        157497
# 45 a 49 anos        153398
# 40 a 44 anos        145095
# 70 a 74 anos        138882
# 35 a 39 anos        131852
# 75 a 79 anos        115217
# 30 a 34 anos        114271
# 25 a 29 anos         94579
# 80 a 84 anos         93251
# 21 a 24 anos         68484
# 85 a 89 anos         68406
# 90 a 94 anos         49497
# 20 anos              38090
# 19 anos              34784
# 95 a 99 anos         32366
# 18 anos              30576
# 17 anos              24112
# 16 anos              17198
# 100 anos ou mais     12613
# Inválido              5153
# Name: DS_FAIXA_ETARIA, dtype: int64

# %%
feminino = df[(df['CD_GENERO']==4)]

# %%
feminino['DS_FAIXA_ETARIA'].value_counts() #juntar com nivel de escolaridade
# Out:
# 55 a 59 anos        188696
# 50 a 54 anos        185884
# 60 a 64 anos        181842
# 45 a 49 anos        176446
# 65 a 69 anos        167944
# 40 a 44 anos        167342
# 35 a 39 anos        152197
# 70 a 74 anos        148378
# 30 a 34 anos        130972
# 75 a 79 anos        124284
# 25 a 29 anos        109742
# 80 a 84 anos        102581
# 21 a 24 anos         83514
# 85 a 89 anos         76831
# 90 a 94 anos         54545
# 20 anos              46303
# 19 anos              41473
# 18 anos              34211
# 95 a 99 anos         33877
# 17 anos              25270
# 16 anos              16794
# 100 anos ou mais     13436
# Inválido              5146
# Name: DS_FAIXA_ETARIA, dtype: int64

# %%
masculino['DS_GRAU_ESCOLARIDADE'].value_counts()
# Out:
# ENSINO FUNDAMENTAL INCOMPLETO    353611
# LÊ E ESCREVE                     287184
# ENSINO MÉDIO COMPLETO            280802
# ENSINO FUNDAMENTAL COMPLETO      253403
# ANALFABETO                       246550
# ENSINO MÉDIO INCOMPLETO          231381
# SUPERIOR COMPLETO                205901
# SUPERIOR INCOMPLETO              162100
# NÃO INFORMADO                      7172
# Name: DS_GRAU_ESCOLARIDADE, dtype: int64

# %%
feminino['DS_GRAU_ESCOLARIDADE'].value_counts()
# Out:
# ENSINO FUNDAMENTAL INCOMPLETO    379235
# ENSINO MÉDIO COMPLETO            334811
# LÊ E ESCREVE                     294863
# ENSINO FUNDAMENTAL COMPLETO      277048
# ANALFABETO                       264617
# ENSINO MÉDIO INCOMPLETO          262668
# SUPERIOR COMPLETO                258495
# SUPERIOR INCOMPLETO              187599
# NÃO INFORMADO                      8372
# Name: DS_GRAU_ESCOLARIDADE, dtype: int64

# %%
df['NM_MUNICIPIO'].value_counts()
# Out:
# SÃO PAULO         67034
# RIO DE JANEIRO    59954
# BELO HORIZONTE    20912
# FORTALEZA         20130
# BRASÍLIA          19102
#                   ...
# RIVERA                1
# CASTRIES              1
# BAMAKO                1
# LETHEM                1
# ADIS ABEBA            1
# Name: NM_MUNICIPIO, Length: 5460, dtype: int64

# %%
cidades= df[df['SG_UF']== 'ZZ']

# %%
cidades.iloc[:,12:25]
# Out:
#         DS_ESTADO_CIVIL  CD_FAIXA_ETARIA DS_FAIXA_ETARIA  \
# 238922         SOLTEIRO             4549    45 a 49 anos
# 238923         SOLTEIRO             5054    50 a 54 anos
# 238924         SOLTEIRO             5054    50 a 54 anos
# 238925         SOLTEIRO             6064    60 a 64 anos
# 238926         SOLTEIRO             6569    65 a 69 anos
# ...                 ...              ...             ...
# 4296683        SOLTEIRO             2124    21 a 24 anos
# 4296684        SOLTEIRO             4044    40 a 44 anos
# 4296685          CASADO             3539    35 a 39 anos
# 4296686          CASADO             4549    45 a 49 anos
# 4296687          CASADO             5559    55 a 59 anos
#
#          CD_GRAU_ESCOLARIDADE     DS_GRAU_ESCOLARIDADE  QT_ELEITORES_PERFIL  \
# 238922                      6    ENSINO MÉDIO COMPLETO                  129
# 238923                      5  ENSINO MÉDIO INCOMPLETO                   29
# ...

# %%
cidades['NM_MUNICIPIO'].value_counts()
# Out:
# NOVA YORK     758
# LISBOA        734
# NAGÓIA        717
# MIAMI         692
# BOSTON        681
#              ...
# ADIS ABEBA      1
# CASTRIES        1
# COBIJA          1
# BAMAKO          1
# LETHEM          1
# Name: NM_MUNICIPIO, Length: 175, dtype: int64

# %%
cidades.groupby('NM_MUNICIPIO').size().sort_values().tail(15).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='NM_MUNICIPIO'>

# %%
cidades['NR_ZONA'].value_counts()
# Out:
# 1    34033
# Name: NR_ZONA, dtype: int64

# %%
#Podemos perceber que esse ano de eleção temos mais mulheres do que homens participando do eleitorado
#Conseguimos ver tambem que a faixa etaria de mulheres é mais jovem que a de homens e tambem possuindo uma nivel de escolaridade
#mais elevado

#Percebemos tambem que existe no banco registro dos cidadãos que moram no exterior e não necessitam participar das eleições
#municipais apenas as eleições para Presidência
